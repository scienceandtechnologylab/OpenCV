# %%
import cv2
import numpy as np

# %%
old_img=cv2.imread("./picture/fb16.jpg")
old_img=cv2.resize(old_img,(500,600))

new_img=cv2.polylines(img=old_img,
                      pts=[np.array([[120,201],[244,35],[370,209],[369,321],[128,325]],dtype=np.int32)],
                      isClosed=True,color=(0,255,0),thickness=3,lineType=16)

cv2.imshow("Image",old_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
