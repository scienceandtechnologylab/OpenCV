# %%
import cv2

# %%
img=cv2.imread("picture/girl_21.jpg")
img=cv2.resize(img,(500,550))
# image এর উপরের বাম কোনা হলো (x1,y1) cordinant এবং নিচের ডান কোনা হলো (x2,y2) cordinant
#img[y1:y2,x1:x2]
crop=img[100:300,180:350]
cv2.imshow("Crop image",crop)

cv2.imshow("Original Image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
