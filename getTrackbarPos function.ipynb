# %%
import cv2
import numpy as np

# %%
def change(x):
    pass

# %%
img=np.zeros((500,500,3),np.uint8)

cv2.namedWindow("bar")
cv2.createTrackbar("on","bar",0,100,change) #cv2.createTrackbar(trackbarName, windowName, value, count, onChange)

while True:
    cv2.imshow("bar",img)
    if cv2.waitKey(1) & 0xff==ord("q"):
        break

    var=cv2.getTrackbarPos("on","bar") # cv2.getTrackbarPos(trackbarname, winname)
    #print(var)
    img[:]=[var,0,0]

cv2.destroyAllWindows()
